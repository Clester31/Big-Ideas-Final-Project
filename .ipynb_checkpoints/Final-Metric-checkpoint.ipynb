# %% [markdown]
# # Imports
#
# Before we can do anything, we gotta do the imports...

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import geopandas as gpd

speed_humps_data = pd.read_csv("Speed-Humps.csv")

# %% [markdown]
# # Data
#
# Now that we have all of our tools in our bag, let's look at the first five columns of our data to see what we're working with:

# %%
speed_humps_data.head()
# Out:
#            id  hump_id  locator_address_number locator_street  pavement  \
# 0   430808404        1                  4337.0      Saline St      9257
# 1  1520886592        2                     NaN   Summerset Dr     15346
# 2   858537521        3                   511.0       Gold Way      1755
# 3   297775878        4                   547.0       Gold Way      1755
# 4  1061197751        5                   593.0       Gold Way      1755
#
#   speed_hump_material         neighborhood  council_district  ward  \
# 0             Asphalt  Squirrel Hill South                 5    14
# 1                 NaN  Squirrel Hill South                 5    14
# 2             Asphalt        North Oakland                 6     5
# 3             Asphalt        North Oakland                 6     5
# 4             Asphalt        North Oakland                 6     5
#
#          tract  public_works_division  pli_division  police_zone fire_zone  \
# 0  42003141400                      3            14            4      2-15
# 1  42003141400                      3            14            4      2-20
# 2  42003562000                      3             5            4      2-23
# 3  42003562000                      3             5            4      2-23
# 4  42003562000                      3             5            4      2-23
#
#     latitude  longitude
# 0  40.419835 -79.926062
# 1  40.425040 -79.912040
# 2  40.456746 -79.954521
# 3  40.457333 -79.954899
# 4  40.458061 -79.955355

# %% [markdown]
# With this dataset, there's not a column that says "speed hump count" or anything, so it doesn't really tell us about the total amount of speed humps each neighborhood has (which is what we really want). So I'll filter for the "neighborhood" column, and see how many entries each neighborhood has by using the \'value_counts\' function.

# %%
speed_humps_data['neighborhood'].value_counts()
# Out:
# Squirrel Hill South    18
# Carrick                 9
# North Oakland           6
# Polish Hill             6
# Brookline               4
# Perry North             4
# Homewood South          4
# Upper Hill              4
# South Side Slopes       4
# Garfield                3
# South Side Flats        3
# Bloomfield              3
# Mount Washington        3
# Squirrel Hill North     3
# Highland Park           2
# Central Oakland         1
# Stanton Heights         1
# Overbrook               1
# Name: neighborhood, dtype: int64

# %% [markdown]
# # Visuals
#
# Now that I have the nice and filtered data, I want to see it visually. I dealt with box plots a lot in high school, so I'll use a box plot to represnt the data!

# %%
speed_humps_data['neighborhood'].value_counts().plot.box()

# %% [markdown]
# ![confusion](https://media.giphy.com/media/1X7lCRp8iE0yrdZvwd/giphy.gif)

# %% [markdown]
# Well that is not very helpful. I'll drop the ".box" part of that plot code.

# %%
speed_humps_data['neighborhood'].value_counts().plot()

# %% [markdown]
# Better, but still not great...
# I'll try the ".bar" function:

# %%
speed_humps_data['neighborhood'].value_counts().plot.bar()

# %% [markdown]
# Perfect.

# %% [markdown]
# # GeoMap

# %%
neighborhoods = gpd.read_file("Neighborhoods/Neighborhoods_.shp")
neighborhoods.plot()
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: Neighborhoods/Neighborhoods_.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-23-f18402aa0c61> in <module>
# ----> 1 neighborhoods = gpd.read_file("Neighborhoods/Neighborhoods_.shp")
#       2 neighborhoods.plot()
#
# /opt/tljh/user/lib/python3.8/site-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, rows, **kwargs)
#      94
#      95     with fiona_env():
# ---> 96         with reader(path_or_bytes, **kwargs) as features:
#      97
#      98             # In a future Fiona release the crs attribute of features will
#
# /opt/tljh/user/lib/python3.8/site-packages/fiona/env.py in wrapper(*args, **kwargs)
#     396     def wrapper(*args, **kwargs):
#     397         if local._env:
# --> 398             return f(*args, **kwargs)
#     399         else:
#     400             if isinstance(args[0], str):
#
# /opt/tljh/user/lib/python3.8/site-packages/fiona/__init__.py in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, **kwargs)
#     251
#     252         if mode in ('a', 'r'):
# --> 253             c = Collection(path, mode, driver=driver, encoding=encoding,
#     254                            layer=layer, enabled_drivers=enabled_drivers, **kwargs)
#     255         elif mode == 'w':
#
# /opt/tljh/user/lib/python3.8/site-packages/fiona/collection.py in __init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, **kwargs)
#     152             if self.mode == 'r':
#     153                 self.session = Session()
# --> 154                 self.session.start(self, **kwargs)
#     155             elif self.mode in ('a', 'w'):
#     156                 self.session = WritingSession()
#
# fiona/ogrext.pyx in fiona.ogrext.Session.start()
#
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# DriverError: Neighborhoods/Neighborhoods_.shp: No such file or directory

# %%
hump_hoods = speed_humps_data['neighborhood'].value_counts().reset_index().rename({'index' : 'neighborhood', 'neighborhood' : 'count'}, axis=1)
hump_hoods
# Out:
#            neighborhood  count
# 0   Squirrel Hill South     18
# 1               Carrick      9
# 2         North Oakland      6
# 3           Polish Hill      6
# 4             Brookline      4
# 5           Perry North      4
# 6        Homewood South      4
# 7            Upper Hill      4
# 8     South Side Slopes      4
# 9              Garfield      3
# 10     South Side Flats      3
# 11           Bloomfield      3
# 12     Mount Washington      3
# 13  Squirrel Hill North      3
# 14        Highland Park      2
# 15      Central Oakland      1
# 16      Stanton Heights      1
# 17            Overbrook      1

# %%
speed_humps_map = neighborhoods.merge(hump_hoods, how='left', left_on = 'hood', right_on = 'neighborhood')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-bc7401622403> in <module>
# ----> 1 speed_humps_map = neighborhoods.merge(hump_hoods, how='left', left_on = 'hood', right_on = 'neighborhood')
#
# /opt/tljh/user/lib/python3.8/site-packages/geopandas/geodataframe.py in merge(self, *args, **kwargs)
#     856
#     857         """
# --> 858         result = DataFrame.merge(self, *args, **kwargs)
#     859         geo_col = self._geometry_column_name
#     860         if isinstance(result, DataFrame) and geo_col in result:
#
# /opt/tljh/user/lib/python3.8/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7282         from pandas.core.reshape.merge import merge
#    7283
# -> 7284         return merge(
#    7285             self,
#    7286             right,
#
# /opt/tljh/user/lib/python3.8/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      71     validate=None,
#      72 ) -> "DataFrame":
# ---> 73     op = _MergeOperation(
#      74         left,
#      75         right,
#
# /opt/tljh/user/lib/python3.8/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     629         # validate the merge keys dtypes. We may need to coerce
#     630         # to avoid incompat dtypes
# --> 631         self._maybe_coerce_merge_keys()
#     632
#     633         # If argument passed to validate,
#
# /opt/tljh/user/lib/python3.8/site-packages/pandas/core/reshape/merge.py in _maybe_coerce_merge_keys(self)
#    1144                     inferred_right in string_types and inferred_left not in string_types
#    1145                 ):
# -> 1146                     raise ValueError(msg)
#    1147
#    1148             # datetimelikes must match exactly
#
# ValueError: You are trying to merge on object and int64 columns. If you wish to proceed you should use pd.concat

# %%
speed_humps_map = pd.concat([hump_hoods, neighborhoods], keys=["df1", 'df2'])
speed_humps_map
# Out:
#                          neighborhood  objectid  fid_blockg statefp10  \
# df1 Squirrel Hill South          18.0       NaN         NaN       NaN
#     Carrick                       9.0       NaN         NaN       NaN
#     Polish Hill                   6.0       NaN         NaN       NaN
#     North Oakland                 6.0       NaN         NaN       NaN
#     South Side Slopes             4.0       NaN         NaN       NaN
# ...                               ...       ...         ...       ...
# df2 85                            NaN      88.0       298.0        42
#     86                            NaN      89.0        32.0        42
#     87                            NaN      90.0        57.0        42
#     88                            NaN      91.0        96.0        42
#     89                            NaN    1292.0         NaN      None
#
#                         countyfp10 tractce10 blkgrpce10       geoid10  \
# df1 Squirrel Hill South        NaN       NaN        NaN           NaN
#     Carrick                    NaN       NaN        NaN           NaN
#     Polish Hill                NaN       NaN        NaN           NaN
#     North Oakland              NaN       NaN        NaN           NaN
#     South Side Slopes          NaN       NaN        NaN           NaN
# ...                            ...       ...        ...           ...
# df2 85                         003    563100          3  420035631003
#     86                         003    562600          1  420035626001
#     87                         003    250700          1  420032507001
#     88                         003    562300          2  420035623002
#     89                        None      None       None          None
#
#                             namelsad10 mtfcc10  ...    shape_ar_1  page_numbe  \
# df1 Squirrel Hill South            NaN     NaN  ...           NaN         NaN
#     Carrick                        NaN     NaN  ...           NaN         NaN
#     Polish Hill                    NaN     NaN  ...           NaN         NaN
#     North Oakland                  NaN     NaN  ...           NaN         NaN
#     South Side Slopes              NaN     NaN  ...           NaN         NaN
# ...                                ...     ...  ...           ...         ...
# df2 85                   Block Group 3   G5030  ...  1.027890e+07        15.0
#     86                   Block Group 1   G5030  ...  5.579501e+06        15.0
#     87                   Block Group 1   G5030  ...  6.050988e+06        15.0
#     88                   Block Group 2   G5030  ...  1.271304e+07        15.0
#     89                            None    None  ...           NaN        15.0
#
#                                     plannerass created_us  \
# df1 Squirrel Hill South                    NaN        NaN
#     Carrick                                NaN        NaN
#     Polish Hill                            NaN        NaN
#     North Oakland                          NaN        NaN
#     South Side Slopes                      NaN        NaN
# ...                                        ...        ...
# df2 85                          Sophia Robison  pgh.admin
#     86                          Sophia Robison  pgh.admin
#     87                   Stephanie Joy Everett  pgh.admin
#     88                           Ose Akinlotan  pgh.admin
#     89                   Stephanie Joy Everett  pgh.admin
#
#                                        created_da  last_edite  \
# df1 Squirrel Hill South                       NaN         NaN
#     Carrick                                   NaN         NaN
#     Polish Hill                               NaN         NaN
#     North Oakland                             NaN         NaN
#     South Side Slopes                         NaN         NaN
# ...                                           ...         ...
# df2 85                   2019-10-23T14:17:16.403Z   pgh.admin
#     86                   2019-10-23T14:17:16.403Z   pgh.admin
#     87                   2019-10-23T14:17:16.403Z   pgh.admin
#     88                   2019-10-23T14:17:16.403Z   pgh.admin
#     89                   2019-10-23T14:17:16.403Z   pgh.admin
#
#                                        last_edi_1    Shape__Are    Shape__Len  \
# df1 Squirrel Hill South                       NaN           NaN           NaN
#     Carrick                                   NaN           NaN           NaN
#     Polish Hill                               NaN           NaN           NaN
#     North Oakland                             NaN           NaN           NaN
#     South Side Slopes                         NaN           NaN           NaN
# ...                                           ...           ...           ...
# df2 85                   2019-10-23T14:17:16.403Z  1.024662e+07  16308.779881
#     86                   2019-10-23T14:17:16.403Z  5.579476e+06  18778.991513
#     87                   2019-10-23T14:17:16.403Z  6.050817e+06  11709.518764
#     88                   2019-10-23T14:17:16.403Z  1.271295e+07  18931.494331
#     89                   2019-10-23T14:17:16.403Z  3.461777e+07  31328.878632
#
#                                                                   geometry
# df1 Squirrel Hill South                                                NaN
#     Carrick                                                            NaN
#     Polish Hill                                                        NaN
#     North Oakland                                                      NaN
#     South Side Slopes                                                  NaN
# ...                                                                    ...
# df2 85                   POLYGON ((-80.0343055321957 40.4336563049974, ...
#     86                   POLYGON ((-80.0286907313636 40.4445374953663, ...
#     87                   POLYGON ((-80.0203893260379 40.4628509728573, ...
#     88                   POLYGON ((-79.92029777945091 40.4120521624107,...
#     89                   POLYGON ((-80.01783332809779 40.4973609794455,...
#
# [108 rows x 39 columns]

# %%
speed_humps_map = hump_hoods.append(neighborhoods)
speed_humps_map.head(20)
# Out:
#                      neighborhood  objectid  fid_blockg statefp10 countyfp10  \
# Squirrel Hill South          18.0       NaN         NaN       NaN        NaN
# Carrick                       9.0       NaN         NaN       NaN        NaN
# Polish Hill                   6.0       NaN         NaN       NaN        NaN
# North Oakland                 6.0       NaN         NaN       NaN        NaN
# South Side Slopes             4.0       NaN         NaN       NaN        NaN
# Perry North                   4.0       NaN         NaN       NaN        NaN
# Upper Hill                    4.0       NaN         NaN       NaN        NaN
# Homewood South                4.0       NaN         NaN       NaN        NaN
# Brookline                     4.0       NaN         NaN       NaN        NaN
# South Side Flats              3.0       NaN         NaN       NaN        NaN
# Bloomfield                    3.0       NaN         NaN       NaN        NaN
# Mount Washington              3.0       NaN         NaN       NaN        NaN
# Garfield                      3.0       NaN         NaN       NaN        NaN
# Squirrel Hill North           3.0       NaN         NaN       NaN        NaN
# Highland Park                 2.0       NaN         NaN       NaN        NaN
# Central Oakland               1.0       NaN         NaN       NaN        NaN
# Stanton Heights               1.0       NaN         NaN       NaN        NaN
# Overbrook                     1.0       NaN         NaN       NaN        NaN
# 0                             NaN       1.0         0.0        42        003
# 1                             NaN       2.0         1.0        42        003
#
#                     tractce10 blkgrpce10       geoid10     namelsad10 mtfcc10  \
# Squirrel Hill South       NaN        NaN           NaN            NaN     NaN
# Carrick                   NaN        NaN           NaN            NaN     NaN
# Polish Hill               NaN        NaN           NaN            NaN     NaN
# North Oakland             NaN        NaN           NaN            NaN     NaN
# South Side Slopes         NaN        NaN           NaN            NaN     NaN
# Perry North               NaN        NaN           NaN            NaN     NaN
# Upper Hill                NaN        NaN           NaN            NaN     NaN
# Homewood South            NaN        NaN           NaN            NaN     NaN
# Brookline                 NaN        NaN           NaN            NaN     NaN
# South Side Flats          NaN        NaN           NaN            NaN     NaN
# Bloomfield                NaN        NaN           NaN            NaN     NaN
# Mount Washington          NaN        NaN           NaN            NaN     NaN
# Garfield                  NaN        NaN           NaN            NaN     NaN
# Squirrel Hill North       NaN        NaN           NaN            NaN     NaN
# Highland Park             NaN        NaN           NaN            NaN     NaN
# Central Oakland           NaN        NaN           NaN            NaN     NaN
# Stanton Heights           NaN        NaN           NaN            NaN     NaN
# Overbrook                 NaN        NaN           NaN            NaN     NaN
# 0                      040500          1  420030405001  Block Group 1   G5030
# 1                      040400          1  420030404001  Block Group 1   G5030
#
#                      ...    shape_ar_1  page_numbe     plannerass created_us  \
# Squirrel Hill South  ...           NaN         NaN            NaN        NaN
# Carrick              ...           NaN         NaN            NaN        NaN
# Polish Hill          ...           NaN         NaN            NaN        NaN
# North Oakland        ...           NaN         NaN            NaN        NaN
# South Side Slopes    ...           NaN         NaN            NaN        NaN
# Perry North          ...           NaN         NaN            NaN        NaN
# Upper Hill           ...           NaN         NaN            NaN        NaN
# Homewood South       ...           NaN         NaN            NaN        NaN
# Brookline            ...           NaN         NaN            NaN        NaN
# South Side Flats     ...           NaN         NaN            NaN        NaN
# Bloomfield           ...           NaN         NaN            NaN        NaN
# Mount Washington     ...           NaN         NaN            NaN        NaN
# Garfield             ...           NaN         NaN            NaN        NaN
# Squirrel Hill North  ...           NaN         NaN            NaN        NaN
# Highland Park        ...           NaN         NaN            NaN        NaN
# Central Oakland      ...           NaN         NaN            NaN        NaN
# Stanton Heights      ...           NaN         NaN            NaN        NaN
# Overbrook            ...           NaN         NaN            NaN        NaN
# 0                    ...  7.843108e+06        15.0  Derek Dauphin  pgh.admin
# 1                    ...  1.390463e+07        15.0  Derek Dauphin  pgh.admin
#
#                                    created_da  last_edite  \
# Squirrel Hill South                       NaN         NaN
# Carrick                                   NaN         NaN
# Polish Hill                               NaN         NaN
# North Oakland                             NaN         NaN
# South Side Slopes                         NaN         NaN
# Perry North                               NaN         NaN
# Upper Hill                                NaN         NaN
# Homewood South                            NaN         NaN
# Brookline                                 NaN         NaN
# South Side Flats                          NaN         NaN
# Bloomfield                                NaN         NaN
# Mount Washington                          NaN         NaN
# Garfield                                  NaN         NaN
# Squirrel Hill North                       NaN         NaN
# Highland Park                             NaN         NaN
# Central Oakland                           NaN         NaN
# Stanton Heights                           NaN         NaN
# Overbrook                                 NaN         NaN
# 0                    2019-10-23T14:17:16.403Z   pgh.admin
# 1                    2019-10-23T14:17:16.403Z   pgh.admin
#
#                                    last_edi_1    Shape__Are    Shape__Len  \
# Squirrel Hill South                       NaN           NaN           NaN
# Carrick                                   NaN           NaN           NaN
# Polish Hill                               NaN           NaN           NaN
# North Oakland                             NaN           NaN           NaN
# South Side Slopes                         NaN           NaN           NaN
# Perry North                               NaN           NaN           NaN
# Upper Hill                                NaN           NaN           NaN
# Homewood South                            NaN           NaN           NaN
# Brookline                                 NaN           NaN           NaN
# South Side Flats                          NaN           NaN           NaN
# Bloomfield                                NaN           NaN           NaN
# Mount Washington                          NaN           NaN           NaN
# Garfield                                  NaN           NaN           NaN
# Squirrel Hill North                       NaN           NaN           NaN
# Highland Park                             NaN           NaN           NaN
# Central Oakland                           NaN           NaN           NaN
# Stanton Heights                           NaN           NaN           NaN
# Overbrook                                 NaN           NaN           NaN
# 0                    2019-10-23T14:17:16.403Z  7.842997e+06  11525.904546
# 1                    2019-10-23T14:17:16.403Z  1.390469e+07  20945.562570
#
#                                                               geometry
# Squirrel Hill South                                                NaN
# Carrick                                                            NaN
# Polish Hill                                                        NaN
# North Oakland                                                      NaN
# South Side Slopes                                                  NaN
# Perry North                                                        NaN
# Upper Hill                                                         NaN
# Homewood South                                                     NaN
# Brookline                                                          NaN
# South Side Flats                                                   NaN
# Bloomfield                                                         NaN
# Mount Washington                                                   NaN
# Garfield                                                           NaN
# Squirrel Hill North                                                NaN
# Highland Park                                                      NaN
# Central Oakland                                                    NaN
# Stanton Heights                                                    NaN
# Overbrook                                                          NaN
# 0                    POLYGON ((-79.9530403037863 40.4420349712273, ...
# 1                    POLYGON ((-79.9545454522395 40.4588227640274, ...
#
# [20 rows x 39 columns]

# %%
speed_humps_map.plot()
